# %% [markdown]
# ## Exercicios sobre Funcao

# %% [markdown]
# ### Suponha que precisemos preparar funcoes de conversao de valores e apresentacao em graficos

# %% [markdown]
# 1 - Conversao de Farenheit para graus Celsius.

# %% [markdown]
# Mesmo hoje em dia, há sistemas que trabalham com Farenheit, mas a maioria das aplicacoes requerem graus Celsius. Sabendo que o valor em graus Celsius equivale a: (Farenheit - 32) x (5/9), desenvolva uma funcao para converter a seguinte lista de valores Farenheit para Celsius.

# %%
Fah = [3,5,15,56,90,104,121]

# %% [markdown]
# Os resultados devem estar em um dataframe, com o qual se deve apresentar um grafico cartersiano, onde o exio X contem o valor em Farenheit e o eixo Y possui o valor convertido em Celsius. Pode-se afirmar que a relacao é linear?

# %% [markdown]
# 2 - Suponha que ha dois conjuntos de dados que precisamos correlacionar, mas nao sabemos uma relacao explicita dessa correlacao. Monte uma funcao que mostra um grafico de correlacao entre dois conjuntos de dados, nas cores azul, verde e laranja, para os seguintes casos:

# %%
A = [1,3,4,8,12,16,29]
B = [30,43,89,99,108]

# %%
C = [3,30,45,87,89,108,210]
D = [3,28,33,78,90,97,110]

# %%
E = [56, 89, 97, 107,208,390]
D = [2,8,67,70,110,154]
