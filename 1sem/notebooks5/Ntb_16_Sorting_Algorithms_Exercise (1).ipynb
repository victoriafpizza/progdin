# %% [markdown]
# ## Tema: avaliar o desempenho dos 3 algoritmos de Sorting, com tres tipos de dados, computando-se o tempo de processamento de cada caso. Mostre os resultados por meio de um grafico de linhas ou um histograma.

# %% [markdown]
# 1 - Uma das formas de se avaliar um algoritmo leva em conta o tempo de processamento. Com o hardware atual, a ordem de grandeza situa-se em milisegundos, mas isso depende do trabalho a ser feito.

# %% [markdown]
# 2 - Use os comandos que computam tempo de execucao, entre o inicio (start) e fim (end) de uma serie de comandos.

# %% [markdown]
# 3 - Os 4 conjuntos de dados:
#
# a) Array = [1,40,39,23,22,41,49,8,3,2,99,88,76,57,87,76]

# %%
b) long_list = [267] * 10**6

# %%
c) list_lengths = [10**n for n in range(1, 7)]

# %%
d) list_2 = [-0.1, -0.8, 0.9, -0.001, -0.09, 0.56]

# %% [markdown]
# 4 - Para uma nova avaliacao do list_lengths, considere:
# list_lengths = [0,10,50,100,500,1000,5000,10000,50000]
